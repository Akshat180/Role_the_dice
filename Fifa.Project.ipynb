# %%
# new project to be done

# %%
import pandas as pd
import numpy as np

# %%
fifa = pd.read_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\FiFa.Dataset.csv')

# %%
fifa
# Out:
#        sofifa_id                                         player_url
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...  \
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32  \
# ...

# %%
fifa.rename(columns = {'sofifa_id':'fifa_id'}, inplace = True)

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa.columns
# Out:
# Index(['fifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
Fifa_age = fifa.age.head(20)
Fifa_name = fifa.short_name.head(20)

# %%
plt.figure(figsize=(25,5)) # figsize = (width,height)
sns.barplot(y= list(Fifa_age) , x= list(Fifa_name)  , data = fifa)
plt.show() 
# This tells about player and their age

# %%
fifa.nationality.value_counts()
# Out:
# nationality
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: count, Length: 162, dtype: int64

# %%
fifa.nationality.value_counts()[0:10]
# Out:
# nationality
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: count, dtype: int64

# %%
fifa.club.head()
# Out:
# 0           FC Barcelona
# 1               Juventus
# 2    Paris Saint-Germain
# 3        Atlético Madrid
# 4            Real Madrid
# Name: club, dtype: object

# %%
sns.set(rc = {'figure.figsize':(10,5)})
sns.countplot(x=fifa.club.head())
plt.show()

# %%
import plotly.graph_objs as go

# %%
fifa.nationality.value_counts()[0:5]
# Out:
# nationality
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: count, dtype: int64

# %%
fifa.nationality.value_counts()[0:5].keys()
#  it gaves the name without values
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object', name='nationality')

# %%
plt.figure(figsize = (10,8))
plt.bar(list(fifa.nationality.value_counts()[0:5].keys()),list(fifa.nationality.value_counts()[0:5]),color = 'red')
# number players nationality
# Out:
# <BarContainer object of 5 artists>

# %%
player_salary = fifa[['short_name','wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary = player_salary.sort_values(by = ['wage_eur'] , ascending = False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize = (10,8))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color = ['blue','red','green','pink','yellow'])
plt.show()
# which player is getting most salary

# %%
fifa['nationality']=='Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %% [markdown]
# # Germany

# %%
# This is for the Germany nationality
Germany = fifa[fifa['nationality']=='Germany']
Germany.head(10)
# Out:
#      fifa_id                                         player_url
# 6     192448  https://sofifa.com/player/192448/marc-andre-te...  \
# 31    167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36    182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37    188350  https://sofifa.com/player/188350/marco-reus/20...
# 49    178603  https://sofifa.com/player/178603/mats-hummels/...
# 55    222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61    212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70    189596  https://sofifa.com/player/189596/thomas-muller...
# 77    212190  https://sofifa.com/player/212190/niklas-sule/2...
# 109   235790  https://sofifa.com/player/235790/kai-havertz/2...
#
#         short_name              long_name  age         dob  height_cm
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187  \
# 31        M. Neuer           Manuel Neuer   33  1986-03-27        193
# ...

# %%
Germany.sort_values(by = ['height_cm'],ascending = False).head()
# Out:
#        fifa_id                                         player_url
# 8016    236831  https://sofifa.com/player/236831/aaron-seydel/...  \
# 1217    200212  https://sofifa.com/player/200212/michael-esser...
# 1389    199833  https://sofifa.com/player/199833/lars-unnersta...
# 11859   167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576   239746  https://sofifa.com/player/239746/lukas-watkowi...
#
#            short_name            long_name  age         dob  height_cm
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199  \
# 1217         M. Esser        Michael Esser   31  1987-11-22        198
# 1389    L. Unnerstall      Lars Unnerstall   28  1990-07-20        198
# 11859  D. Stroh-Engel  Dominik Stroh-Engel   33  1985-11-27        197
# 13576    L. Watkowiak      Lukas Watkowiak   23  1996-03-06        197
#
#        weight_kg nationality                club  ...   lwb   ldm   cdm   rdm
# ...

# %%
Germany.sort_values(by = ['weight_kg'],ascending = False).head()
# Out:
#        fifa_id                                         player_url
# 13576   239746  https://sofifa.com/player/239746/lukas-watkowi...  \
# 1389    199833  https://sofifa.com/player/199833/lars-unnersta...
# 518     179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217    200212  https://sofifa.com/player/200212/michael-esser...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
#
#           short_name        long_name  age         dob  height_cm  weight_kg
# 13576   L. Watkowiak  Lukas Watkowiak   23  1996-03-06        197        103  \
# 1389   L. Unnerstall  Lars Unnerstall   28  1990-07-20        198        103
# 518      R. Fährmann    Ralf Fährmann   30  1988-09-27        197         98
# 1217        M. Esser    Michael Esser   31  1987-11-22        198         97
# 77           N. Süle      Niklas Süle   23  1995-09-03        195         97
#
#       nationality                club  ...   lwb   ldm   cdm   rdm   rwb
# ...

# %%
Germany.sort_values(by = ['wage_eur'],ascending = False).head()
# Out:
#      fifa_id                                         player_url
# 36    182521  https://sofifa.com/player/182521/toni-kroos/20...  \
# 6     192448  https://sofifa.com/player/192448/marc-andre-te...
# 55    222492  https://sofifa.com/player/222492/leroy-sane/20...
# 146   186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 70    189596  https://sofifa.com/player/189596/thomas-muller...
#
#         short_name              long_name  age         dob  height_cm
# 36        T. Kroos             Toni Kroos   29  1990-01-04        183  \
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 55         L. Sané             Leroy Sané   23  1996-01-11        183
# 146    I. Gündoğan         İlkay Gündoğan   28  1990-10-24        180
# 70       T. Müller          Thomas Müller   29  1989-09-13        186
#
#      weight_kg nationality               club  ...   lwb   ldm   cdm   rdm
# 36          76     Germany        Real Madrid  ...  75+3  79+3  79+3  79+3  \
# ...

# %%
Gd=Germany[['short_name','wage_eur']].sort_values(by = ['wage_eur'],ascending = False).head()
Gd
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000

# %%
plt.figure(figsize = (10,7))
plt.bar(list(Gd['short_name'])[0:5],list(Gd['wage_eur']),color = 'black')
plt.show()
# highest salary paid to german player

# %% [markdown]
# # Shooting

# %%
# best player for shooting skills

player_shooting = fifa[['short_name','shooting']]
player_shooting
# Out:
#               short_name  shooting
# 0               L. Messi      92.0
# 1      Cristiano Ronaldo      93.0
# 2              Neymar Jr      85.0
# 3               J. Oblak       NaN
# 4              E. Hazard      83.0
# ...                  ...       ...
# 18273         Shao Shuai      23.0
# 18274       Xiao Mingjie      24.0
# 18275          Zhang Wei      35.0
# 18276       Wang Haijian      35.0
# 18277         Pan Ximing      32.0
#
# [18278 rows x 2 columns]

# %%
PS1= player_shooting.sort_values(by = ['shooting'], ascending = False).head()

# %% [markdown]
# # Defending

# %%
player_defending = fifa[['short_name','defending','nationality','club']]

# %%
Pd1=player_defending.sort_values(by = ['defending'],ascending = False).head()
Pd1
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
real_madrid = fifa[fifa['club']=='Real Madrid']

# %%
Rm1 = real_madrid.sort_values(by = ['wage_eur'], ascending = False).head()
Rm1
# Out:
#     fifa_id                                         player_url    short_name
# 4    183277  https://sofifa.com/player/183277/eden-hazard/2...     E. Hazard  \
# 8    177003  https://sofifa.com/player/177003/luka-modric/2...     L. Modrić
# 36   182521  https://sofifa.com/player/182521/toni-kroos/20...      T. Kroos
# 18   155862  https://sofifa.com/player/155862/sergio-ramos-...  Sergio Ramos
# 46   165153  https://sofifa.com/player/165153/karim-benzema...    K. Benzema
#
#               long_name  age         dob  height_cm  weight_kg nationality
# 4           Eden Hazard   28  1991-01-07        175         74     Belgium  \
# 8           Luka Modrić   33  1985-09-09        172         66     Croatia
# 36           Toni Kroos   29  1990-01-04        183         76     Germany
# 18  Sergio Ramos García   33  1986-03-30        184         82       Spain
# 46        Karim Benzema   31  1987-12-19        185         81      France
#
# ...

# %%
Rm =real_madrid.sort_values(by = ['shooting'], ascending = False).head()
Rm[['short_name','shooting']]
# Out:
#        short_name  shooting
# 100       G. Bale      87.0
# 106  J. Rodríguez      86.0
# 4       E. Hazard      83.0
# 46     K. Benzema      82.0
# 161      L. Jović      82.0

# %%
plt.figure(figsize = (10,8))
plt.bar(list(Rm['short_name'])[0:5],list(Rm['shooting'])[0:5],color = ['blue','red','green','pink','yellow'])
plt.show()

# %%
Rd2 = real_madrid.sort_values(by = ['defending'], ascending = False).head()
Rd2[['short_name','defending']]
# Out:
#        short_name  defending
# 18   Sergio Ramos       87.0
# 42       Casemiro       85.0
# 76      R. Varane       85.0
# 94       Carvajal       82.0
# 332  Éder Militão       81.0

# %%
real_madrid.nationality.value_counts()
# Out:
# nationality
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Costa Rica             1
# Wales                  1
# Colombia               1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10,8))
plt.bar(list(Rm1['short_name'])[0:5],list(Rm1['wage_eur']),color = ['blue','red','green','pink','yellow'])
plt.show()
# this for page getting high pay in real madrid

# %%
plt.figure(figsize = (10,8))
plt.bar(list(Pd1['short_name'])[0:5],list(Pd1['defending']),color = ['blue','red','green','pink','yellow'])
plt.show()
# player who have good defending skills in all

# %%
plt.figure(figsize = (10,8))
plt.bar(list(Rd2['short_name'])[0:5],list(Rd2['defending']),color = ['blue','red','green','pink','yellow'])
plt.show()
# player who defend good in real madrid

# %% [markdown]
# # club

# %%
FiFa1 = fifa.sort_values(by = ['wage_eur'], ascending = False).head()
FiFa1
# Out:
#     fifa_id                                         player_url
# 0    158023  https://sofifa.com/player/158023/lionel-messi/...  \
# 4    183277  https://sofifa.com/player/183277/eden-hazard/2...
# 1     20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 5    192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 22   194765  https://sofifa.com/player/194765/antoine-griez...
#
#            short_name                            long_name  age         dob
# 0            L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24  \
# 4           E. Hazard                          Eden Hazard   28  1991-01-07
# 1   Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 5        K. De Bruyne                      Kevin De Bruyne   28  1991-06-28
# 22       A. Griezmann                    Antoine Griezmann   28  1991-03-21
#
#     height_cm  weight_kg nationality             club  ...   lwb   ldm   cdm
# ...

# %%
FiFa1[['club','wage_eur']]
# Out:
#                club  wage_eur
# 0      FC Barcelona    565000
# 4       Real Madrid    470000
# 1          Juventus    405000
# 5   Manchester City    370000
# 22     FC Barcelona    370000

# %%
fifa.club
# Out:
# 0                         FC Barcelona
# 1                             Juventus
# 2                  Paris Saint-Germain
# 3                      Atlético Madrid
# 4                          Real Madrid
#                      ...
# 18273                 Beijing Renhe FC
# 18274                 Shanghai SIPG FC
# 18275           Hebei China Fortune FC
# 18276    Shanghai Greenland Shenhua FC
# 18277           Hebei China Fortune FC
# Name: club, Length: 18278, dtype: object

# %%
plt.figure(figsize = (15,8))
plt.bar(list(FiFa1['club'])[0:4],list(FiFa1['wage_eur'])[0:4],color = ['blue','red','green','purple'])
plt.show()
# club who pay good to player
